# %% [markdown]
# <a href="https://colab.research.google.com/github/BondaiKa/Car-Model-Classification/blob/master/MainWorker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os 
import tensorflow_addons as tfa
import tensorflow_addons as tfma

# %matplotlib inline
# %load_ext tensorboard

# %%
print(tf.config.list_physical_devices("GPU"))
print(tf.config.list_logical_devices("CPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
DATASET_DIR = "./GRZ_and_model_recognition/test"
NUM_CLASSES = 11
BATCH_SIZE = 256

# %%
data_dir = os.listdir(DATASET_DIR+'/train')
data_dir
# Out:
# ['KAMAZ_ALLKAMAZ_C',
#  'LADA_PRIORA_B',
#  'MAZDA_3_B',
#  'RЕNАULТ_DUSТЕR_B',
#  'SCANIA_ALLSCANIA_C',
#  'TOYOTA_RАV4_B',
#  'VOLVO_ALLVOLVO_C',
#  'VОLКSWАGЕN_TIGUAN_B',
#  'VОLКSWАGЕN_РОLО_B',
#  'КIА_RIО_B',
#  'НУUNDАI_SОLАRIS_B']

# %%
TRAIN_PATH = DATASET_DIR + '/train'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  TRAIN_PATH,
  batch_size = BATCH_SIZE
)
# Out:
# Found 176 files belonging to 11 classes.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['KAMAZ_ALLKAMAZ_C',
#  'LADA_PRIORA_B',
#  'MAZDA_3_B',
#  'RЕNАULТ_DUSТЕR_B',
#  'SCANIA_ALLSCANIA_C',
#  'TOYOTA_RАV4_B',
#  'VOLVO_ALLVOLVO_C',
#  'VОLКSWАGЕN_TIGUAN_B',
#  'VОLКSWАGЕN_РОLО_B',
#  'КIА_RIО_B',
#  'НУUNDАI_SОLАRIS_B']

# %%
VAL_PATH = DATASET_DIR + '/val'
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  VAL_PATH,
  batch_size = BATCH_SIZE
)
# Out:
# Found 176 files belonging to 11 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    print(images[0].shape)
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# (256, 256, 3)

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (176, 256, 256, 3)
# (176,)

# %%
logdir = "logs/test-pipeline"
checkpoint_path = "models/test/training__{epoch:02d}__{loss:.6f}/cp.ckpt"


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=7,monitor='val_loss')
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, verbose=1, mode='auto',
    min_delta=0.0001, cooldown=0, min_lr=0
)

# %%
alex_model = tf.keras.models.Sequential([
    # 1st conv
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(256, 256, 3)),
  tf.keras.layers.Conv2D(96, (11,11),strides=(4,4), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2,2)),
    # 2nd conv
  tf.keras.layers.Conv2D(256, (11,11),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
     # 3rd conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 4th conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 5th Conv
  tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2, 2)),
    # To Flatten layer
  tf.keras.layers.Flatten(),
    # To FC layer 1
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.5),
    #To FC layer 2
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
alex_model.compile(
    optimizer=tf.optimizers.SGD(lr=0.001),
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)
alex_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 62, 62, 96)        34944
# _________________________________________________________________
# batch_normalization (BatchNo (None, 62, 62, 96)        384
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 31, 31, 256)       2973952
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 31, 31, 256)       1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 31, 31, 384)       885120
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 31, 31, 384)       1536
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 31, 31, 384)       1327488
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 31, 31, 384)       1536
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 31, 31, 256)       884992
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 31, 31, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               14745856
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 11)                2827
# =================================================================
# Total params: 20,926,475
# Trainable params: 20,923,723
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
with tf.device('/device:GPU:0'):
    alex_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[
            tensorboard_callback, 
            cp_callback, 
            early_stop_callback, 
            reduce_lr_callback
        ],
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 2.4211 - accuracy: 0.0966
# Epoch 00001: saving model to models/test/training__01__2.421084\cp.ckpt
# 1/1 [==============================] - 5s 5s/step - loss: 2.4211 - accuracy: 0.0966 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 2/100
# WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 1/1 [==============================] - ETA: 0s - loss: 2.4186 - accuracy: 0.0966
# Epoch 00002: saving model to models/test/training__02__2.418573\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.4186 - accuracy: 0.0966 - val_loss: 2.3978 - val_accuracy: 0.1250
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 2.4218 - accuracy: 0.0739
# Epoch 00003: saving model to models/test/training__03__2.421796\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.4218 - accuracy: 0.0739 - val_loss: 2.3978 - val_accuracy: 0.1193
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 2.4116 - accuracy: 0.1307
# Epoch 00004: saving model to models/test/training__04__2.411588\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.4116 - accuracy: 0.1307 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 2.3944 - accuracy: 0.1420
# Epoch 00005: saving model to models/test/training__05__2.394361\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.3944 - accuracy: 0.1420 - val_loss: 2.3978 - val_accuracy: 0.0852
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 2.4063 - accuracy: 0.1136
# Epoch 00006: saving model to models/test/training__06__2.406332\cp.ckpt
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1/1 [==============================] - 2s 2s/step - loss: 2.4063 - accuracy: 0.1136 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 2.3929 - accuracy: 0.1250
# Epoch 00007: saving model to models/test/training__07__2.392870\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.3929 - accuracy: 0.1250 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 2.3859 - accuracy: 0.1136
# Epoch 00008: saving model to models/test/training__08__2.385931\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.3859 - accuracy: 0.1136 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 2.3971 - accuracy: 0.1364
# Epoch 00009: saving model to models/test/training__09__2.397051\cp.ckpt
# 1/1 [==============================] - 2s 2s/step - loss: 2.3971 - accuracy: 0.1364 - val_loss: 2.3979 - val_accuracy: 0.0909

# %%
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 10352), started 4 days, 19:55:44 ago. (Use '!kill 10352' to kill it.)
#       <iframe id="tensorboard-frame-71ecce0d8ba03ef5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-71ecce0d8ba03ef5");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
