# %% [markdown]
# <a href="https://colab.research.google.com/github/BondaiKa/Car-Model-Classification/blob/master/MainWorker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os 
import tensorflow_addons as tfa
import tensorflow_addons as tfma

# %matplotlib inline
# %load_ext tensorboard

# %%
print(tf.config.list_physical_devices("GPU"))
print(tf.config.list_logical_devices("CPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
DATASET_DIR = "./GRZ_and_model_recognition/learn"
NUM_CLASSES = 11
BATCH_SIZE = 32

# %%
data_dir = os.listdir(DATASET_DIR+'/train')
data_dir
# Out:
# ['KAMAZ_ALLKAMAZ_C',
#  'LADA_PRIORA_B',
#  'MAZDA_3_B',
#  'RЕNАULТ_DUSТЕR_B',
#  'SCANIA_ALLSCANIA_C',
#  'TOYOTA_RАV4_B',
#  'VOLVO_ALLVOLVO_C',
#  'VОLКSWАGЕN_TIGUAN_B',
#  'VОLКSWАGЕN_РОLО_B',
#  'КIА_RIО_B',
#  'НУUNDАI_SОLАRIS_B']

# %%
TRAIN_PATH = DATASET_DIR + '/train'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  TRAIN_PATH,
  batch_size = BATCH_SIZE,
  image_size=(299, 299)
)
# Out:
# Found 140727 files belonging to 11 classes.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['KAMAZ_ALLKAMAZ_C',
#  'LADA_PRIORA_B',
#  'MAZDA_3_B',
#  'RЕNАULТ_DUSТЕR_B',
#  'SCANIA_ALLSCANIA_C',
#  'TOYOTA_RАV4_B',
#  'VOLVO_ALLVOLVO_C',
#  'VОLКSWАGЕN_TIGUAN_B',
#  'VОLКSWАGЕN_РОLО_B',
#  'КIА_RIО_B',
#  'НУUNDАI_SОLАRIS_B']

# %%
VAL_PATH = DATASET_DIR + '/val'
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  VAL_PATH,
  batch_size = BATCH_SIZE,
  image_size=(299, 299)
)
# Out:
# Found 15643 files belonging to 11 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    print(images[0].shape)
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# (256, 256, 3)

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 256, 256, 3)
# (64,)

# %%
logdir = "logs/alexnet-model"
checkpoint_path = "models/alexnet/training__{epoch:02d}__{loss:.6f}/cp.ckpt"


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=4,monitor='val_loss')
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2, verbose=1, mode='auto',
    min_delta=0.0001, cooldown=0, min_lr=0.00001
)

# %%
alex_model = tf.keras.models.Sequential([
    # 1st conv
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(256, 256, 3)),
  tf.keras.layers.Conv2D(96, (11,11),strides=(4,4), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2,2)),
    # 2nd conv
  tf.keras.layers.Conv2D(256, (11,11),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
     # 3rd conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 4th conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 5th Conv
  tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2, 2)),
    # To Flatten layer
  tf.keras.layers.Flatten(),
    # To FC layer 1
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.5),
    #To FC layer 2
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
alex_model.compile(
    optimizer=tf.optimizers.SGD(),
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)
alex_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 62, 62, 96)        34944
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 62, 62, 96)        384
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 96)        0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 31, 31, 256)       2973952
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 31, 31, 256)       1024
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 31, 31, 384)       885120
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 31, 31, 384)       1536
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 31, 31, 384)       1327488
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 31, 31, 384)       1536
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 31, 31, 256)       884992
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 31, 31, 256)       1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               14745856
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 11)                2827
# =================================================================
# Total params: 20,926,475
# Trainable params: 20,923,723
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
alex_model.load_weights('./models/alexnet/training__06__1.945134/cp.ckpt')

# %%
with tf.device('/device:GPU:0'):
    alex_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[
            tensorboard_callback, 
            cp_callback, 
            early_stop_callback, 
            reduce_lr_callback
        ],
)
# Out:
# Epoch 1/100
# 1100/1100 [==============================] - ETA: 0s - loss: 2.2375 - accuracy: 0.2980
# Epoch 00001: saving model to models/alexnet/training__01__2.237530\cp.ckpt
# 1100/1100 [==============================] - 3227s 3s/step - loss: 2.2375 - accuracy: 0.2980 - val_loss: 2.3679 - val_accuracy: 0.1745
# Epoch 2/100
# 1100/1100 [==============================] - ETA: 0s - loss: 2.1330 - accuracy: 0.4062
# Epoch 00002: saving model to models/alexnet/training__02__2.132964\cp.ckpt
# 1100/1100 [==============================] - 2917s 3s/step - loss: 2.1330 - accuracy: 0.4062 - val_loss: 2.1827 - val_accuracy: 0.3533
# Epoch 3/100
# 1100/1100 [==============================] - ETA: 0s - loss: 2.0780 - accuracy: 0.4611
# Epoch 00003: saving model to models/alexnet/training__03__2.078028\cp.ckpt
# 1100/1100 [==============================] - 2924s 3s/step - loss: 2.0780 - accuracy: 0.4611 - val_loss: 2.2513 - val_accuracy: 0.2881
# Epoch 4/100
# 1100/1100 [==============================] - ETA: 0s - loss: 2.0229 - accuracy: 0.5174
# Epoch 00004: saving model to models/alexnet/training__04__2.022889\cp.ckpt
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 1100/1100 [==============================] - 2959s 3s/step - loss: 2.0229 - accuracy: 0.5174 - val_loss: 2.3175 - val_accuracy: 0.2225
# Epoch 5/100
# 1100/1100 [==============================] - ETA: 0s - loss: 1.9710 - accuracy: 0.5703
# Epoch 00005: saving model to models/alexnet/training__05__1.970975\cp.ckpt
# 1100/1100 [==============================] - 2938s 3s/step - loss: 1.9710 - accuracy: 0.5703 - val_loss: 2.4038 - val_accuracy: 0.1389
# Epoch 6/100
# 1100/1100 [==============================] - ETA: 0s - loss: 1.9451 - accuracy: 0.5965
# Epoch 00006: saving model to models/alexnet/training__06__1.945134\cp.ckpt
# 1100/1100 [==============================] - 2960s 3s/step - loss: 1.9451 - accuracy: 0.5965 - val_loss: 2.0676 - val_accuracy: 0.4705
# Epoch 7/100
#   10/1100 [..............................] - ETA: 42:47 - loss: 1.9046 - accuracy: 0.6367
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-e1b3a8cbd39e> in <module>
#       1 with tf.device('/device:GPU:0'):
# ----> 2     alex_model.fit(
#       3         train_ds,
#       4         validation_data=val_ds,
#       5         epochs=100,
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
alex_model.save('./models/alexnet/final-alexnet-model')
# Out:
# INFO:tensorflow:Assets written to: ./models/alexnet/final-alexnet-model\assets

# %%
# %tensorboard --logdir=logs/ --host 0.0.0.0
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 10980.

# %%
logdir = "logs/vgg-model-1" 
checkpoint_path = "models/vgg/training__{epoch:02d}__{val_accuracy:.6f}/cp.ckpt"


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=6,monitor='val_loss')
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=4, verbose=1, mode='auto',
    min_delta=0.0001, cooldown=0, min_lr=0
)

# %%
vgg_model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(input_shape=(256, 256, 3), filters=64, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPool2D(pool_size=2,strides=2),

  tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

  tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

  tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
  tf.keras.layers.ZeroPadding2D(padding=1),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

  tf.keras.layers.Flatten(),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(units=256, activation="relu"),
  tf.keras.layers.Dense(units=256, activation="relu"),
  tf.keras.layers.Dense(units=NUM_CLASSES, activation="softmax")
])

# %%
vgg_model.compile(
    optimizer=tf.optimizers.SGD(),
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)
vgg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 256, 256, 64)      1792
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 256, 256, 32)      18464
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 128, 128, 64)      18496
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 16, 256)       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 18, 18, 256)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 9, 9, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 20736)             0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 20736)             82944
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               5308672
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_8 (Dense)              (None, 11)                2827
# =================================================================
# Total params: 7,385,771
# Trainable params: 7,341,547
# Non-trainable params: 44,224
# _________________________________________________________________

# %%
with tf.device('/device:GPU:0'):
    vgg_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[
            tensorboard_callback, 
            cp_callback, 
            early_stop_callback,
            reduce_lr_callback
        ],
)
# Out:
# Epoch 1/100
#    1/4398 [..............................] - ETA: 0s - loss: 2.3995 - accuracy: 0.0938WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 4398/4398 [==============================] - ETA: 0s - loss: 2.0121 - accuracy: 0.5356
# Epoch 00001: saving model to models/vgg/training__01__0.620469\cp.ckpt
# 4398/4398 [==============================] - 5097s 1s/step - loss: 2.0121 - accuracy: 0.5356 - val_loss: 1.9244 - val_accuracy: 0.6205
# Epoch 2/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.7525 - accuracy: 0.7973
# Epoch 00002: saving model to models/vgg/training__02__0.762769\cp.ckpt
# 4398/4398 [==============================] - 76514s 17s/step - loss: 1.7525 - accuracy: 0.7973 - val_loss: 1.7836 - val_accuracy: 0.7628
# Epoch 3/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6807 - accuracy: 0.8661
# Epoch 00003: saving model to models/vgg/training__03__0.795308\cp.ckpt
# 4398/4398 [==============================] - 4094s 931ms/step - loss: 1.6807 - accuracy: 0.8661 - val_loss: 1.7510 - val_accuracy: 0.7953
# Epoch 4/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6538 - accuracy: 0.8916
# Epoch 00004: saving model to models/vgg/training__04__0.844659\cp.ckpt
# 4398/4398 [==============================] - 3996s 909ms/step - loss: 1.6538 - accuracy: 0.8916 - val_loss: 1.7017 - val_accuracy: 0.8447
# Epoch 5/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6406 - accuracy: 0.9042
# Epoch 00005: saving model to models/vgg/training__05__0.875408\cp.ckpt
# 4398/4398 [==============================] - 3990s 907ms/step - loss: 1.6406 - accuracy: 0.9042 - val_loss: 1.6697 - val_accuracy: 0.8754
# Epoch 6/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6332 - accuracy: 0.9110
# Epoch 00006: saving model to models/vgg/training__06__0.883143\cp.ckpt
# 4398/4398 [==============================] - 3993s 908ms/step - loss: 1.6332 - accuracy: 0.9110 - val_loss: 1.6609 - val_accuracy: 0.8831
# Epoch 7/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6282 - accuracy: 0.9156
# Epoch 00007: saving model to models/vgg/training__07__0.870166\cp.ckpt
# 4398/4398 [==============================] - 3999s 909ms/step - loss: 1.6282 - accuracy: 0.9156 - val_loss: 1.6743 - val_accuracy: 0.8702
# Epoch 8/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6252 - accuracy: 0.9183
# Epoch 00008: saving model to models/vgg/training__08__0.888960\cp.ckpt
# 4398/4398 [==============================] - 4085s 929ms/step - loss: 1.6252 - accuracy: 0.9183 - val_loss: 1.6557 - val_accuracy: 0.8890
# Epoch 9/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6221 - accuracy: 0.9210
# Epoch 00009: saving model to models/vgg/training__09__0.879882\cp.ckpt
# 4398/4398 [==============================] - 4023s 915ms/step - loss: 1.6221 - accuracy: 0.9210 - val_loss: 1.6640 - val_accuracy: 0.8799
# Epoch 10/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6207 - accuracy: 0.9223
# Epoch 00010: saving model to models/vgg/training__10__0.898293\cp.ckpt
# 4398/4398 [==============================] - 4010s 912ms/step - loss: 1.6207 - accuracy: 0.9223 - val_loss: 1.6453 - val_accuracy: 0.8983
# Epoch 11/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6193 - accuracy: 0.9234
# Epoch 00011: saving model to models/vgg/training__11__0.898677\cp.ckpt
# 4398/4398 [==============================] - 4017s 913ms/step - loss: 1.6193 - accuracy: 0.9234 - val_loss: 1.6443 - val_accuracy: 0.8987
# Epoch 12/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6185 - accuracy: 0.9243
# Epoch 00012: saving model to models/vgg/training__12__0.894905\cp.ckpt
# 4398/4398 [==============================] - 46973s 11s/step - loss: 1.6185 - accuracy: 0.9243 - val_loss: 1.6492 - val_accuracy: 0.8949
# Epoch 13/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6175 - accuracy: 0.9250
# Epoch 00013: saving model to models/vgg/training__13__0.900786\cp.ckpt
# 4398/4398 [==============================] - 4088s 929ms/step - loss: 1.6175 - accuracy: 0.9250 - val_loss: 1.6426 - val_accuracy: 0.9008
# Epoch 14/100
#   44/4398 [..............................] - ETA: 58:25 - loss: 1.6122 - accuracy: 0.9304
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-b434e0b54cdd> in <module>
#       1 with tf.device('/device:GPU:0'):
# ----> 2     vgg_model.fit(
#       3         train_ds,
#       4         validation_data=val_ds,
#       5         epochs=100,
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
vgg_model.save('models/vgg/final-vgg-model')
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/vgg/final-vgg-model\assets

# %%
# %tensorboard --logdir logs/vgg-model-1/
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 1264.

# %%
logdir = "logs/inceptionv3"
checkpoint_path = "models/inceptionv3/training__{epoch:02d}__{loss:.6f}/cp.ckpt"


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_best_only=True,
    verbose=1
)
early_stop_callback = tf.keras.callbacks.EarlyStopping(
    patience=7,
    restore_best_weights=True
)
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, patience=3, verbose=0, mode='auto',
    min_delta=0.0001, cooldown=0, min_lr=0.00001
    
)

# %%
inceptionv3_model = tf.keras.applications.InceptionV3(
    include_top=True, weights=None, input_tensor=None, input_shape=None,
    pooling=None, classes=NUM_CLASSES, classifier_activation='softmax'
)

# %%
inceptionv3_model.compile(
    optimizer=tf.optimizers.SGD(),
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
with tf.device('/device:GPU:0'):
    inceptionv3_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[tensorboard_callback, cp_callback, early_stop_callback,reduce_lr_callback],
)
# Out:
# Epoch 1/100
#    1/4398 [..............................] - ETA: 4s - loss: 2.4024 - accuracy: 0.0938WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 4398/4398 [==============================] - ETA: 0s - loss: 2.1438 - accuracy: 0.3985
# Epoch 00001: val_loss improved from inf to 2.23437, saving model to models/inceptionv3/training__01__2.143767\cp.ckpt
# 4398/4398 [==============================] - 4720s 1s/step - loss: 2.1438 - accuracy: 0.3985 - val_loss: 2.2344 - val_accuracy: 0.3057
# Epoch 2/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.9727 - accuracy: 0.5716
# Epoch 00002: val_loss improved from 2.23437 to 1.94021, saving model to models/inceptionv3/training__02__1.972717\cp.ckpt
# 4398/4398 [==============================] - 4601s 1s/step - loss: 1.9727 - accuracy: 0.5716 - val_loss: 1.9402 - val_accuracy: 0.6026
# Epoch 3/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.7617 - accuracy: 0.7882
# Epoch 00003: val_loss improved from 1.94021 to 1.81273, saving model to models/inceptionv3/training__03__1.761694\cp.ckpt
# 4398/4398 [==============================] - 4621s 1s/step - loss: 1.7617 - accuracy: 0.7882 - val_loss: 1.8127 - val_accuracy: 0.7347
# Epoch 4/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6928 - accuracy: 0.8554
# Epoch 00004: val_loss did not improve from 1.81273
# 4398/4398 [==============================] - 4604s 1s/step - loss: 1.6928 - accuracy: 0.8554 - val_loss: 1.8924 - val_accuracy: 0.6526
# Epoch 5/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6489 - accuracy: 0.8968
# Epoch 00005: val_loss improved from 1.81273 to 1.69680, saving model to models/inceptionv3/training__05__1.648873\cp.ckpt
# 4398/4398 [==============================] - 4607s 1s/step - loss: 1.6489 - accuracy: 0.8968 - val_loss: 1.6968 - val_accuracy: 0.8492
# Epoch 6/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6381 - accuracy: 0.9060
# Epoch 00006: val_loss improved from 1.69680 to 1.65238, saving model to models/inceptionv3/training__06__1.638076\cp.ckpt
# 4398/4398 [==============================] - 4616s 1s/step - loss: 1.6381 - accuracy: 0.9060 - val_loss: 1.6524 - val_accuracy: 0.8909
# Epoch 7/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6317 - accuracy: 0.9119
# Epoch 00007: val_loss did not improve from 1.65238
# 4398/4398 [==============================] - 48560s 11s/step - loss: 1.6317 - accuracy: 0.9119 - val_loss: 1.6580 - val_accuracy: 0.8854
# Epoch 8/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6287 - accuracy: 0.9146
# Epoch 00008: val_loss improved from 1.65238 to 1.64753, saving model to models/inceptionv3/training__08__1.628706\cp.ckpt
# 4398/4398 [==============================] - 5046s 1s/step - loss: 1.6287 - accuracy: 0.9146 - val_loss: 1.6475 - val_accuracy: 0.8956
# Epoch 9/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.6168 - accuracy: 0.9280
# Epoch 00009: val_loss improved from 1.64753 to 1.62204, saving model to models/inceptionv3/training__09__1.616763\cp.ckpt
# 4398/4398 [==============================] - 4852s 1s/step - loss: 1.6168 - accuracy: 0.9280 - val_loss: 1.6220 - val_accuracy: 0.9234
# Epoch 10/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.5919 - accuracy: 0.9537
# Epoch 00010: val_loss improved from 1.62204 to 1.61778, saving model to models/inceptionv3/training__10__1.591910\cp.ckpt
# 4398/4398 [==============================] - 4851s 1s/step - loss: 1.5919 - accuracy: 0.9537 - val_loss: 1.6178 - val_accuracy: 0.9282
# Epoch 11/100
# 4398/4398 [==============================] - ETA: 0s - loss: 1.5873 - accuracy: 0.9571
# Epoch 00011: val_loss improved from 1.61778 to 1.60530, saving model to models/inceptionv3/training__11__1.587300\cp.ckpt
# 4398/4398 [==============================] - 4824s 1s/step - loss: 1.5873 - accuracy: 0.9571 - val_loss: 1.6053 - val_accuracy: 0.9390
# Epoch 12/100
#  266/4398 [>.............................] - ETA: 1:20:39 - loss: 1.5815 - accuracy: 0.9626

# %%
inceptionv3_model.load_weights('./models/inceptionv3/training__11__1.587300/cp.ckpt')

# %%
inceptionv3_model.save('./models/inceptionv3/inceptionv3_final')
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\User\.conda\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./models/inceptionv3/inceptionv3_final\assets

# %%
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 10668), started 0:00:40 ago. (Use '!kill 10668' to kill it.)
#       <iframe id="tensorboard-frame-23feda61bc54b43a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-23feda61bc54b43a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
